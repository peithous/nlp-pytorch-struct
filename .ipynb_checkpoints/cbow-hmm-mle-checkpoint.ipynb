# %%
import time
from torch.utils.tensorboard import SummaryWriter
import torchtext.data as data
from torchtext.data import BucketIterator
import torch
import torch.nn as nn
from torch_struct import HMM, LinearChainCRF
import matplotlib.pyplot as plt
from torch_struct.data import ConllXDatasetPOS

# start_time = time.time()
device='cpu'

# %%
WORD = data.Field(init_token='<bos>', pad_token=None, eos_token='<eos>') #init_token='<bos>', 
POS = data.Field(init_token='<bos>', include_lengths=True, pad_token=None, eos_token='<eos>') 

fields = (('word', WORD), ('pos', POS), (None, None))
train = ConllXDatasetPOS('data/wsj.train0.conllx', fields, 
                filter_pred=lambda x: len(x.word) < 50) #en_ewt-ud-train.conllu
test = ConllXDatasetPOS('data/wsj.test0.conllx', fields)
print('total train sentences', len(train))
print('total test sentences', len(test))

WORD.build_vocab(train) # 
POS.build_vocab(train, min_freq = 5, max_size=7)
train_iter = BucketIterator(train, batch_size=20, device=device, shuffle=False)
test_iter = BucketIterator(test, batch_size=20, device=device, shuffle=False)

C = len(POS.vocab)
V = len(WORD.vocab)

# t0 = time.time() - start_time
# print(t0)
# Out:
# total train sentences 1174
# total test sentences 45

# %%
# vars(WORD.vocab).keys()

# %%
# type(set(WORD.vocab.itos))

# %%
# set(WORD.vocab.itos)

# %%
# vars(train_iter)

# %%
# batch = next(iter(train_iter))
# batch

# %%
# batch.word

# %%
# label, lengths = batch.pos
# lengths

# %%
# for b in range(batch.word.shape[1]):
#     print(batch.word[:lengths[b], b], '\n')

# %%
cbow_data = []
for ex in train_iter:
#    print(ex.pos)
    words = ex.word
    label, lengths = ex.pos
    
    for b in range(ex.word.shape[1]):
        for i in range(2, lengths[b]-2):
            context = torch.stack((ex.word[i-2, b], ex.word[i-1, b], ex.word[i+1, b], ex.word[i+2, b]))
            target = ex.word[i, b]
            cbow_data.append((context, target))
cbow_data
# Out:
# [(tensor([  1,  70, 572, 411]), tensor(36)),
#  (tensor([  70,   36,  411, 1406]), tensor(572)),
#  (tensor([  36,  572, 1406,    6]), tensor(411)),
#  (tensor([572, 411,   6,  16]), tensor(1406)),
#  (tensor([ 411, 1406,   16,   12]), tensor(6)),
#  (tensor([1406,    6,   12, 3125]), tensor(16)),
#  (tensor([   6,   16, 3125,   17]), tensor(12)),
#  (tensor([16, 12, 17, 26]), tensor(3125)),
#  (tensor([  12, 3125,   26, 1096]), tensor(17)),
#  (tensor([3125,   17, 1096,   11]), tensor(26)),
#  (tensor([  17,   26,   11, 2955]), tensor(1096)),
#  (tensor([  26, 1096, 2955, 3362]), tensor(11)),
#  (tensor([1096,   11, 3362,   60]), tensor(2955)),
#  (tensor([  11, 2955,   60,   16]), tensor(3362)),
#  (tensor([2955, 3362,   16, 3263]), tensor(60)),
#  (tensor([3362,   60, 3263, 2810]), tensor(16)),
#  (tensor([  60,   16, 2810, 3352]), tensor(3263)),
#  (tensor([  16, 3263, 3352,    4]), tensor(2810)),
#  (tensor([3263, 2810,    4, 3325]), tensor(3352)),
#  (tensor([2810, 3352, 3325,   10]), tensor(4)),
#  (tensor([3352,    4,   10, 3422]), tensor(3325)),
#  (tensor([   4, 3325, 3422, 2808]), tensor(10)),
#  (tensor([3325,   10, 2808,    3]), tensor(3422)),
#  (tensor([  10, 3422,    3,   17]), tensor(2808)),
#  (tensor([3422, 2808,   17, 3066]), tensor(3)),
#  (tensor([2808,    3, 3066,  112]), tensor(17)),
#  (tensor([   3,   17,  112, 2722]), tensor(3066)),
#  (tensor([  17, 3066, 2722,   61]), tensor(112)),
#  (tensor([3066,  112,   61,    3]), tensor(2722)),
#  (tensor([ 112, 2722,    3,    4]), tensor(61)),
#  (tensor([2722,   61,    4, 1408]), tensor(3)),
#  (tensor([  61,    3, 1408,    6]), tensor(4)),
#  (tensor([   3,    4,    6, 2796]), tensor(1408)),
#  (tensor([   4, 1408, 2796,    3]), tensor(6)),
#  (tensor([1408,    6,    3, 1375]), tensor(2796)),
#  (tensor([   6, 2796, 1375,   20]), tensor(3)),
#  (tensor([2796,    3,   20, 3043]), tensor(1375)),
#  (tensor([   3, 1375, 3043, 2794]), tensor(20)),
#  (tensor([1375,   20, 2794,    3]), tensor(3043)),
#  (tensor([  20, 3043,    3,   22]), tensor(2794)),
#  (tensor([3043, 2794,   22, 2085]), tensor(3)),
#  (tensor([2794,    3, 2085, 1788]), tensor(22)),
#  (tensor([   3,   22, 1788,    7]), tensor(2085)),
#  (tensor([  22, 2085,    7, 2803]), tensor(1788)),
#  (tensor([2085, 1788, 2803, 1617]), tensor(7)),
#  (tensor([1788,    7, 1617,    5]), tensor(2803)),
#  (tensor([   7, 2803,    5,    2]), tensor(1617)),
#  (tensor([   1,  365, 1377, 2889]), tensor(1617)),
#  (tensor([ 365, 1617, 2889,    5]), tensor(1377)),
#  (tensor([1617, 1377,    5,    2]), tensor(2889)),
#  (tensor([   1, 3270, 2793,   86]), tensor(1130)),
#  (tensor([3270, 1130,   86,   19]), tensor(2793)),
#  (tensor([1130, 2793,   19,   27]), tensor(86)),
#  (tensor([2793,   86,   27,  753]), tensor(19)),
#  (tensor([ 86,  19, 753,  40]), tensor(27)),
#  (tensor([19, 27, 40, 47]), tensor(753)),
#  (tensor([ 27, 753,  47, 135]), tensor(40)),
#  (tensor([753,  40, 135,   7]), tensor(47)),
#  (tensor([ 40,  47,   7, 806]), tensor(135)),
#  (tensor([  47,  135,  806, 1434]), tensor(7)),
#  (tensor([ 135,    7, 1434,   26]), tensor(806)),
#  (tensor([  7, 806,  26,  53]), tensor(1434)),
#  (tensor([ 806, 1434,   53, 2389]), tensor(26)),
#  (tensor([1434,   26, 2389, 1215]), tensor(53)),
#  (tensor([  26,   53, 1215,   10]), tensor(2389)),
#  (tensor([  53, 2389,   10,  672]), tensor(1215)),
#  (tensor([2389, 1215,  672,    5]), tensor(10)),
#  (tensor([1215,   10,    5,    2]), tensor(672)),
#  (tensor([  1,  12, 325, 260]), tensor(1341)),
#  (tensor([  12, 1341,  260,  148]), tensor(325)),
#  (tensor([1341,  325,  148,   56]), tensor(260)),
#  (tensor([325, 260,  56, 191]), tensor(148)),
#  (tensor([ 260,  148,  191, 2390]), tensor(56)),
#  (tensor([ 148,   56, 2390, 1215]), tensor(191)),
#  (tensor([  56,  191, 1215,   10]), tensor(2390)),
#  (tensor([ 191, 2390,   10,    4]), tensor(1215)),
#  (tensor([2390, 1215,    4,   47]), tensor(10)),
#  (tensor([1215,   10,   47,    2]), tensor(4)),
#  (tensor([   1, 2984,    3,   82]), tensor(3136)),
#  (tensor([2984, 3136,   82,    9]), tensor(3)),
#  (tensor([3136,    3,    9,  137]), tensor(82)),
#  (tensor([  3,  82, 137, 206]), tensor(9)),
#  (tensor([ 82,   9, 206, 186]), tensor(137)),
#  (tensor([  9, 137, 186,   3]), tensor(206)),
#  (tensor([137, 206,   3,  19]), tensor(186)),
#  (tensor([206, 186,  19,  31]), tensor(3)),
#  (tensor([ 186,    3,   31, 1766]), tensor(19)),
#  (tensor([   3,   19, 1766,  436]), tensor(31)),
#  (tensor([ 19,  31, 436,  13]), tensor(1766)),
#  (tensor([  31, 1766,   13,    4]), tensor(436)),
#  (tensor([1766,  436,    4, 1341]), tensor(13)),
#  (tensor([ 436,   13, 1341,  325]), tensor(4)),
#  (tensor([ 13,   4, 325, 260]), tensor(1341)),
#  (tensor([   4, 1341,  260,   10]), tensor(325)),
#  (tensor([1341,  325,   10,  682]), tensor(260)),
#  (tensor([325, 260, 682,   9]), tensor(10)),
#  (tensor([260,  10,   9, 198]), tensor(682)),
#  (tensor([ 10, 682, 198,   3]), tensor(9)),
#  (tensor([682,   9,   3,   9]), tensor(198)),
#  (tensor([  9, 198,   9,  10]), tensor(3)),
#  (tensor([ 198,    3,   10, 2909]), tensor(9)),
#  (tensor([   3,    9, 2909,  468]), tensor(10)),
#  (tensor([  9,  10, 468, 233]), tensor(2909)),
#  (tensor([  10, 2909,  233,    5]), tensor(468)),
#  (tensor([2909,  468,    5,    2]), tensor(233)),
#  (tensor([   1, 2736,   86,  623]), tensor(2994)),
#  (tensor([2736, 2994,  623,   40]), tensor(86)),
#  (tensor([2994,   86,   40,  800]), tensor(623)),
#  (tensor([ 86, 623, 800,   7]), tensor(40)),
#  (tensor([623,  40,   7, 120]), tensor(800)),
#  (tensor([ 40, 800, 120, 204]), tensor(7)),
#  (tensor([800,   7, 204,  21]), tensor(120)),
#  (tensor([   7,  120,   21, 1040]), tensor(204)),
#  (tensor([ 120,  204, 1040,  204]), tensor(21)),
#  (tensor([204,  21, 204,   8]), tensor(1040)),
#  (tensor([  21, 1040,    8,   87]), tensor(204)),
#  (tensor([1040,  204,   87,    5]), tensor(8)),
#  (tensor([204,   8,   5,   2]), tensor(87)),
#  (tensor([  1,  12, 140,  33]), tensor(63)),
#  (tensor([12, 63, 33, 23]), tensor(140)),
#  (tensor([  63,  140,   23, 1371]), tensor(33)),
#  (tensor([ 140,   33, 1371, 1598]), tensor(23)),
#  (tensor([  33,   23, 1598,  270]), tensor(1371)),
#  (tensor([  23, 1371,  270,    5]), tensor(1598)),
#  (tensor([1371, 1598,    5,    2]), tensor(270)),
#  (tensor([   1,  133, 1881,   35]), tensor(519)),
#  (tensor([133, 519,  35,  37]), tensor(1881)),
#  (tensor([ 519, 1881,   37,   64]), tensor(35)),
#  (tensor([1881,   35,   64,  400]), tensor(37)),
#  (tensor([ 35,  37, 400,   5]), tensor(64)),
#  (tensor([37, 64,  5,  2]), tensor(400)),
#  (tensor([   1, 2751,  226,   10]), tensor(3)),
#  (tensor([2751,    3,   10,  874]), tensor(226)),
#  (tensor([  3, 226, 874, 849]), tensor(10)),
#  (tensor([226,  10, 849,   3]), tensor(874)),
#  (tensor([ 10, 874,   3, 778]), tensor(849)),
#  (tensor([874, 849, 778,   9]), tensor(3)),
#  (tensor([ 849,    3,    9, 4048]), tensor(778)),
#  (tensor([   3,  778, 4048, 1260]), tensor(9)),
#  (tensor([ 778,    9, 1260,    3]), tensor(4048)),
#  (tensor([   9, 4048,    3,  228]), tensor(1260)),
#  (tensor([4048, 1260,  228,    9]), tensor(3)),
#  (tensor([1260,    3,    9,  927]), tensor(228)),
#  (tensor([  3, 228, 927, 451]), tensor(9)),
#  (tensor([228,   9, 451,   5]), tensor(927)),
#  (tensor([  9, 927,   5,   2]), tensor(451)),
#  (tensor([   1,  473, 1769,    7]), tensor(32)),
#  (tensor([473,  32,   7,   4]), tensor(1769)),
#  (tensor([  32, 1769,    4,  476]), tensor(7)),
#  (tensor([1769,    7,  476,    9]), tensor(4)),
#  (tensor([  7,   4,   9, 471]), tensor(476)),
#  (tensor([  4, 476, 471, 860]), tensor(9)),
#  (tensor([476,   9, 860,  75]), tensor(471)),
#  (tensor([  9, 471,  75,   7]), tensor(860)),
#  (tensor([ 471,  860,    7, 1333]), tensor(75)),
#  (tensor([ 860,   75, 1333,   58]), tensor(7)),
#  (tensor([  75,    7,   58, 1171]), tensor(1333)),
#  (tensor([   7, 1333, 1171,    7]), tensor(58)),
#  (tensor([1333,   58,    7,  499]), tensor(1171)),
#  (tensor([  58, 1171,  499,   53]), tensor(7)),
#  (tensor([1171,    7,   53,  115]), tensor(499)),
#  (tensor([  7, 499, 115, 643]), tensor(53)),
#  (tensor([499,  53, 643,   9]), tensor(115)),
#  (tensor([ 53, 115,   9, 135]), tensor(643)),
#  (tensor([115, 643, 135,  20]), tensor(9)),
#  (tensor([643,   9,  20, 431]), tensor(135)),
#  (tensor([  9, 135, 431, 500]), tensor(20)),
#  (tensor([135,  20, 500,   5]), tensor(431)),
#  (tensor([ 20, 431,   5,   2]), tensor(500)),
#  (tensor([   1,  133, 1022,    7]), tensor(245)),
#  (tensor([ 133,  245,    7, 1913]), tensor(1022)),
#  (tensor([ 245, 1022, 1913, 2203]), tensor(7)),
#  (tensor([1022,    7, 2203, 2205]), tensor(1913)),
#  (tensor([   7, 1913, 2205,   13]), tensor(2203)),
#  (tensor([1913, 2203,   13,   74]), tensor(2205)),
#  (tensor([2203, 2205,   74,   43]), tensor(13)),
#  (tensor([2205,   13,   43,  293]), tensor(74)),
#  (tensor([ 13,  74, 293,  41]), tensor(43)),
#  (tensor([  74,   43,   41, 5616]), tensor(293)),
#  (tensor([  43,  293, 5616,    4]), tensor(41)),
#  (tensor([ 293,   41,    4, 2341]), tensor(5616)),
#  (tensor([  41, 5616, 2341,    6]), tensor(4)),
#  (tensor([5616,    4,    6,  499]), tensor(2341)),
#  (tensor([   4, 2341,  499,   24]), tensor(6)),
#  (tensor([2341,    6,   24, 2022]), tensor(499)),
#  (tensor([   6,  499, 2022, 2324]), tensor(24)),
#  (tensor([ 499,   24, 2324,   29]), tensor(2022)),
#  (tensor([  24, 2022,   29,    8]), tensor(2324)),
#  (tensor([2022, 2324,    8, 5416]), tensor(29)),
#  (tensor([2324,   29, 5416, 2318]), tensor(8)),
#  (tensor([  29,    8, 2318,    3]), tensor(5416)),
#  (tensor([   8, 5416,    3, 1311]), tensor(2318)),
#  (tensor([5416, 2318, 1311,  111]), tensor(3)),
#  (tensor([2318,    3,  111,    9]), tensor(1311)),
#  (tensor([   3, 1311,    9, 5004]), tensor(111)),
#  (tensor([1311,  111, 5004,  134]), tensor(9)),
#  (tensor([ 111,    9,  134, 1345]), tensor(5004)),
#  (tensor([   9, 5004, 1345, 1863]), tensor(134)),
#  (tensor([5004,  134, 1863,    5]), tensor(1345)),
#  (tensor([ 134, 1345,    5,    2]), tensor(1863)),
#  (tensor([   1,  478,    4, 1774]), tensor(116)),
#  (tensor([ 478,  116, 1774,   10]), tensor(4)),
#  (tensor([116,   4,  10, 986]), tensor(1774)),
#  (tensor([   4, 1774,  986,    7]), tensor(10)),
#  (tensor([1774,   10,    7,    4]), tensor(986)),
#  (tensor([ 10, 986,   4, 224]), tensor(7)),
#  (tensor([986,   7, 224,  53]), tensor(4)),
#  (tensor([  7,   4,  53, 651]), tensor(224)),
#  (tensor([  4, 224, 651, 328]), tensor(53)),
#  (tensor([224,  53, 328, 308]), tensor(651)),
#  (tensor([ 53, 651, 308,  42]), tensor(328)),
#  (tensor([651, 328,  42, 212]), tensor(308)),
#  (tensor([ 328,  308,  212, 1048]), tensor(42)),
#  (tensor([ 308,   42, 1048,   14]), tensor(212)),
#  (tensor([ 42, 212,  14,   3]), tensor(1048)),
#  (tensor([ 212, 1048,    3,  374]), tensor(14)),
#  (tensor([1048,   14,  374,   67]), tensor(3)),
#  (tensor([ 14,   3,  67, 658]), tensor(374)),
#  (tensor([  3, 374, 658,   3]), tensor(67)),
#  (tensor([374,  67,   3,  41]), tensor(658)),
#  (tensor([  67,  658,   41, 4178]), tensor(3)),
#  (tensor([ 658,    3, 4178,  210]), tensor(41)),
#  (tensor([   3,   41,  210, 4710]), tensor(4178)),
#  (tensor([  41, 4178, 4710,  293]), tensor(210)),
#  (tensor([4178,  210,  293,   21]), tensor(4710)),
#  (tensor([ 210, 4710,   21, 2203]), tensor(293)),
#  (tensor([4710,  293, 2203, 2324]), tensor(21)),
#  (tensor([ 293,   21, 2324,   10]), tensor(2203)),
#  (tensor([  21, 2203,   10,   58]), tensor(2324)),
#  (tensor([2203, 2324,   58,  235]), tensor(10)),
#  (tensor([2324,   10,  235,  114]), tensor(58)),
#  (tensor([ 10,  58, 114, 154]), tensor(235)),
#  (tensor([ 58, 235, 154,  73]), tensor(114)),
#  (tensor([235, 114,  73,   5]), tensor(154)),
#  (tensor([114, 154,   5,   2]), tensor(73)),
#  (tensor([  1,  12, 328,  71]), tensor(308)),
#  (tensor([ 12, 308,  71,  41]), tensor(328)),
#  (tensor([308, 328,  41, 586]), tensor(71)),
#  (tensor([328,  71, 586, 293]), tensor(41)),
#  (tensor([ 71,  41, 293,   7]), tensor(586)),
#  (tensor([ 41, 586,   7, 236]), tensor(293)),
#  (tensor([ 586,  293,  236, 4182]), tensor(7)),
#  (tensor([ 293,    7, 4182,    6]), tensor(236)),
#  (tensor([  7, 236,   6, 446]), tensor(4182)),
#  (tensor([ 236, 4182,  446,  440]), tensor(6)),
#  (tensor([4182,    6,  440,    9]), tensor(446)),
#  (tensor([  6, 446,   9, 258]), tensor(440)),
#  (tensor([ 446,  440,  258, 1005]), tensor(9)),
#  (tensor([ 440,    9, 1005,    5]), tensor(258)),
#  (tensor([  9, 258,   5,   2]), tensor(1005)),
#  (tensor([  1, 571,   4, 986]), tensor(6)),
#  (tensor([ 571,    6,  986, 2065]), tensor(4)),
#  (tensor([   6,    4, 2065,   14]), tensor(986)),
#  (tensor([   4,  986,   14, 2032]), tensor(2065)),
#  (tensor([ 986, 2065, 2032, 3859]), tensor(14)),
#  (tensor([2065,   14, 3859,   35]), tensor(2032)),
#  (tensor([  14, 2032,   35,   64]), tensor(3859)),
#  (tensor([2032, 3859,   64,  118]), tensor(35)),
#  (tensor([3859,   35,  118, 5269]), tensor(64)),
#  (tensor([  35,   64, 5269,   20]), tensor(118)),
#  (tensor([ 64, 118,  20,   4]), tensor(5269)),
#  (tensor([ 118, 5269,    4, 1066]), tensor(20)),
#  (tensor([5269,   20, 1066,  115]), tensor(4)),
#  (tensor([ 20,   4, 115,  84]), tensor(1066)),
#  (tensor([   4, 1066,   84, 3910]), tensor(115)),
#  (tensor([1066,  115, 3910,   66]), tensor(84)),
#  (tensor([115,  84,  66,   9]), tensor(3910)),
#  (tensor([  84, 3910,    9,    4]), tensor(66)),
#  (tensor([3910,   66,    4,  233]), tensor(9)),
#  (tensor([ 66,   9, 233, 906]), tensor(4)),
#  (tensor([  9,   4, 906, 118]), tensor(233)),
#  (tensor([   4,  233,  118, 5378]), tensor(906)),
#  (tensor([ 233,  906, 5378,  113]), tensor(118)),
#  (tensor([906, 118, 113,   4]), tensor(5378)),
#  (tensor([ 118, 5378,    4,  302]), tensor(113)),
#  (tensor([5378,  113,  302, 1992]), tensor(4)),
#  (tensor([ 113,    4, 1992,   66]), tensor(302)),
#  (tensor([  4, 302,  66,  14]), tensor(1992)),
#  (tensor([ 302, 1992,   14,  202]), tensor(66)),
#  (tensor([1992,   66,  202, 3952]), tensor(14)),
#  (tensor([  66,   14, 3952,   10]), tensor(202)),
#  (tensor([ 14, 202,  10, 499]), tensor(3952)),
#  (tensor([ 202, 3952,  499,   24]), tensor(10)),
#  (tensor([3952,   10,   24, 2023]), tensor(499)),
#  (tensor([  10,  499, 2023, 2130]), tensor(24)),
#  (tensor([ 499,   24, 2130,  158]), tensor(2023)),
#  (tensor([  24, 2023,  158, 5017]), tensor(2130)),
#  (tensor([2023, 2130, 5017, 4485]), tensor(158)),
#  (tensor([2130,  158, 4485,    7]), tensor(5017)),
#  (tensor([ 158, 5017,    7,  296]), tensor(4485)),
#  (tensor([5017, 4485,  296,   79]), tensor(7)),
#  (tensor([4485,    7,   79,    6]), tensor(296)),
#  (tensor([   7,  296,    6, 1046]), tensor(79)),
#  (tensor([ 296,   79, 1046, 1765]), tensor(6)),
#  (tensor([  79,    6, 1765,    5]), tensor(1046)),
#  (tensor([   6, 1046,    5,    2]), tensor(1765)),
#  (tensor([  1,  16, 245,  35]), tensor(12)),
#  (tensor([  16,   12,   35, 4415]), tensor(245)),
#  (tensor([  12,  245, 4415,  347]), tensor(35)),
#  (tensor([ 245,   35,  347, 4807]), tensor(4415)),
#  (tensor([  35, 4415, 4807,    7]), tensor(347)),
#  (tensor([4415,  347,    7,    4]), tensor(4807)),
#  (tensor([ 347, 4807,    4, 2006]), tensor(7)),
#  (tensor([4807,    7, 2006,    6]), tensor(4)),
#  (tensor([7, 4, 6, 8]), tensor(2006)),
#  (tensor([   4, 2006,    8,  442]), tensor(6)),
#  (tensor([2006,    6,  442, 1016]), tensor(8)),
#  (tensor([   6,    8, 1016,  334]), tensor(442)),
#  (tensor([  8, 442, 334,   3]), tensor(1016)),
#  (tensor([ 442, 1016,    3,   17]), tensor(334)),
#  (tensor([1016,  334,   17,  410]), tensor(3)),
#  (tensor([ 334,    3,  410, 2812]), tensor(17)),
#  (tensor([   3,   17, 2812, 1698]), tensor(410)),
#  (tensor([  17,  410, 1698, 3102]), tensor(2812)),
#  (tensor([ 410, 2812, 3102,    6]), tensor(1698)),
#  (tensor([2812, 1698,    6, 3423]), tensor(3102)),
#  (tensor([1698, 3102, 3423,    3]), tensor(6)),
#  (tensor([3102,    6,    3, 2999]), tensor(3423)),
#  (tensor([   6, 3423, 2999,    3]), tensor(3)),
#  (tensor([3423,    3,    3,   10]), tensor(2999)),
#  (tensor([   3, 2999,   10,   55]), tensor(3)),
#  (tensor([2999,    3,   55,    6]), tensor(10)),
#  (tensor([ 3, 10,  6,  4]), tensor(55)),
#  (tensor([  10,   55,    4, 1532]), tensor(6)),
#  (tensor([  55,    6, 1532,  986]), tensor(4)),
#  (tensor([  6,   4, 986,   4]), tensor(1532)),
#  (tensor([   4, 1532,    4,  224]), tensor(986)),
#  (tensor([1532,  986,  224,   35]), tensor(4)),
#  (tensor([986,   4,  35, 647]), tensor(224)),
#  (tensor([  4, 224, 647, 265]), tensor(35)),
#  (tensor([224,  35, 265,   4]), tensor(647)),
#  (tensor([ 35, 647,   4, 328]), tensor(265)),
#  (tensor([647, 265, 328,  49]), tensor(4)),
#  (tensor([265,   4,  49, 308]), tensor(328)),
#  (tensor([   4,  328,  308, 1542]), tensor(49)),
#  (tensor([ 328,   49, 1542, 1498]), tensor(308)),
#  (tensor([  49,  308, 1498,    5]), tensor(1542)),
#  (tensor([ 308, 1542,    5,    2]), tensor(1498)),
#  (tensor([   1,   16,    4, 1846]), tensor(2712)),
#  (tensor([  16, 2712, 1846,  288]), tensor(4)),
#  (tensor([2712,    4,  288,   75]), tensor(1846)),
#  (tensor([   4, 1846,   75, 1028]), tensor(288)),
#  (tensor([1846,  288, 1028,  735]), tensor(75)),
#  (tensor([288,  75, 735,  10]), tensor(1028)),
#  (tensor([  75, 1028,   10,   42]), tensor(735)),
#  (tensor([1028,  735,   42, 2006]), tensor(10)),
#  (tensor([ 735,   10, 2006,    5]), tensor(42)),
#  (tensor([10, 42,  5, 17]), tensor(2006)),
#  (tensor([  42, 2006,   17,    2]), tensor(5)),
#  (tensor([   1, 2840,    4,  652]), tensor(3)),
#  (tensor([2840,    3,  652,  967]), tensor(4)),
#  (tensor([  3,   4, 967, 293]), tensor(652)),
#  (tensor([  4, 652, 293,   3]), tensor(967)),
#  (tensor([652, 967,   3, 608]), tensor(293)),
#  (tensor([967, 293, 608,   9]), tensor(3)),
#  (tensor([293,   3,   9,  67]), tensor(608)),
#  (tensor([  3, 608,  67, 431]), tensor(9)),
#  (tensor([608,   9, 431, 500]), tensor(67)),
#  (tensor([  9,  67, 500,   7]), tensor(431)),
#  (tensor([ 67, 431,   7, 236]), tensor(500)),
#  (tensor([431, 500, 236, 643]), tensor(7)),
#  (tensor([500,   7, 643,   9]), tensor(236)),
#  (tensor([  7, 236,   9, 135]), tensor(643)),
#  (tensor([236, 643, 135,   6]), tensor(9)),
#  (tensor([643,   9,   6,  58]), tensor(135)),
#  (tensor([  9, 135,  58, 114]), tensor(6)),
#  (tensor([135,   6, 114, 154]), tensor(58)),
#  (tensor([  6,  58, 154,  73]), tensor(114)),
#  (tensor([ 58, 114,  73, 832]), tensor(154)),
#  (tensor([114, 154, 832,  53]), tensor(73)),
#  (tensor([154,  73,  53,   8]), tensor(832)),
#  (tensor([ 73, 832,   8, 150]), tensor(53)),
#  (tensor([832,  53, 150,  97]), tensor(8)),
#  (tensor([53,  8, 97,  4]), tensor(150)),
#  (tensor([  8, 150,   4, 266]), tensor(97)),
#  (tensor([150,  97, 266,   5]), tensor(4)),
#  (tensor([97,  4,  5,  2]), tensor(266)),
#  (tensor([  1,  68, 545,  15]), tensor(53)),
#  (tensor([68, 53, 15,  6]), tensor(545)),
#  (tensor([ 53, 545,   6,   4]), tensor(15)),
#  (tensor([545,  15,   4, 500]), tensor(6)),
#  (tensor([ 15,   6, 500,   3]), tensor(4)),
#  (tensor([  6,   4,   3, 247]), tensor(500)),
#  (tensor([  4, 500, 247,   7]), tensor(3)),
#  (tensor([500,   3,   7, 245]), tensor(247)),
#  (tensor([  3, 247, 245, 615]), tensor(7)),
#  (tensor([247,   7, 615,   3]), tensor(245)),
#  (tensor([  7, 245,   3, 493]), tensor(615)),
#  (tensor([245, 615, 493,  58]), tensor(3)),
#  (tensor([615,   3,  58, 520]), tensor(493)),
#  (tensor([  3, 493, 520, 342]), tensor(58)),
#  (tensor([493,  58, 342,   5]), tensor(520)),
#  (tensor([ 58, 520,   5,   2]), tensor(342)),
#  (tensor([  1,  12,  49, 308]), tensor(328)),
#  (tensor([ 12, 328, 308,  10]), tensor(49)),
#  (tensor([328,  49,  10,  36]), tensor(308)),
#  (tensor([  49,  308,   36, 1918]), tensor(10)),
#  (tensor([ 308,   10, 1918,    7]), tensor(36)),
#  (tensor([  10,   36,    7, 5426]), tensor(1918)),
#  (tensor([  36, 1918, 5426,  295]), tensor(7)),
#  (tensor([1918,    7,  295, 1813]), tensor(5426)),
#  (tensor([   7, 5426, 1813,    9]), tensor(295)),
#  (tensor([5426,  295,    9,  737]), tensor(1813)),
#  (tensor([ 295, 1813,  737, 3833]), tensor(9)),
#  (tensor([1813,    9, 3833,   20]), tensor(737)),
#  (tensor([  9, 737,  20,   4]), tensor(3833)),
#  (tensor([ 737, 3833,    4,  293]), tensor(20)),
#  (tensor([3833,   20,  293,   16]), tensor(4)),
#  (tensor([20,  4, 16, 52]), tensor(293)),
#  (tensor([  4, 293,  52,  32]), tensor(16)),
#  (tensor([ 293,   16,   32, 1028]), tensor(52)),
#  (tensor([  16,   52, 1028,  929]), tensor(32)),
#  (tensor([ 52,  32, 929,   4]), tensor(1028)),
#  (tensor([  32, 1028,    4, 5286]), tensor(929)),
#  (tensor([1028,  929, 5286,    3]), tensor(4)),
#  (tensor([929,   4,   3,  17]), tensor(5286)),
#  (tensor([   4, 5286,   17,   19]), tensor(3)),
#  (tensor([5286,    3,   19, 2766]), tensor(17)),
#  (tensor([   3,   17, 2766,  568]), tensor(19)),
#  (tensor([ 17,  19, 568,   3]), tensor(2766)),
#  (tensor([  19, 2766,    3,  528]), tensor(568)),
#  (tensor([2766,  568,  528, 1871]), tensor(3)),
#  (tensor([ 568,    3, 1871,   26]), tensor(528)),
#  (tensor([  3, 528,  26,   4]), tensor(1871)),
#  (tensor([ 528, 1871,    4,  245]), tensor(26)),
#  (tensor([1871,   26,  245,   11]), tensor(4)),
#  (tensor([ 26,   4,  11, 509]), tensor(245)),
#  (tensor([  4, 245, 509,   6]), tensor(11)),
#  (tensor([ 245,   11,    6, 4027]), tensor(509)),
#  (tensor([  11,  509, 4027,  794]), tensor(6)),
#  (tensor([509,   6, 794,   3]), tensor(4027)),
#  (tensor([   6, 4027,    3,   45]), tensor(794)),
#  (tensor([4027,  794,   45,  308]), tensor(3)),
#  (tensor([794,   3, 308,   4]), tensor(45)),
#  (tensor([  3,  45,   4, 328]), tensor(308)),
#  (tensor([ 45, 308, 328,   5]), tensor(4)),
#  (tensor([308,   4,   5,   2]), tensor(328)),
#  (tensor([   1,  473,  134, 1345]), tensor(3)),
#  (tensor([ 473,    3, 1345,    9]), tensor(134)),
#  (tensor([  3, 134,   9, 431]), tensor(1345)),
#  (tensor([ 134, 1345,  431,  305]), tensor(9)),
#  (tensor([1345,    9,  305,   50]), tensor(431)),
#  (tensor([  9, 431,  50, 534]), tensor(305)),
#  (tensor([431, 305, 534, 532]), tensor(50)),
#  (tensor([305,  50, 532,   7]), tensor(534)),
#  (tensor([ 50, 534,   7, 933]), tensor(532)),
#  (tensor([534, 532, 933,  24]), tensor(7)),
#  (tensor([532,   7,  24,   4]), tensor(933)),
#  (tensor([   7,  933,    4, 2168]), tensor(24)),
#  (tensor([ 933,   24, 2168,    3]), tensor(4)),
#  (tensor([24,  4,  3,  9]), tensor(2168)),
#  (tensor([   4, 2168,    9,    4]), tensor(3)),
#  (tensor([2168,    3,    4,  105]), tensor(9)),
#  (tensor([  3,   9, 105,  35]), tensor(4)),
#  (tensor([  9,   4,  35, 518]), tensor(105)),
#  (tensor([  4, 105, 518,  46]), tensor(35)),
#  (tensor([ 105,   35,   46, 1343]), tensor(518)),
#  (tensor([  35,  518, 1343,   51]), tensor(46)),
#  (tensor([518,  46,  51, 725]), tensor(1343)),
#  (tensor([  46, 1343,  725,  202]), tensor(51)),
#  (tensor([1343,   51,  202,   67]), tensor(725)),
#  (tensor([ 51, 725,  67, 105]), tensor(202)),
#  (tensor([725, 202, 105,  10]), tensor(67)),
#  (tensor([ 202,   67,   10, 2080]), tensor(105)),
#  (tensor([  67,  105, 2080,    3]), tensor(10)),
#  (tensor([105,  10,   3,  28]), tensor(2080)),
#  (tensor([  10, 2080,   28,  568]), tensor(3)),
#  (tensor([2080,    3,  568,   19]), tensor(28)),
#  (tensor([ 3, 28, 19,  5]), tensor(568)),
#  (tensor([ 28, 568,   5,   2]), tensor(19)),
#  (tensor([  1,  12,  33, 641]), tensor(245)),
#  (tensor([  12,  245,  641, 1059]), tensor(33)),
#  (tensor([ 245,   33, 1059,   24]), tensor(641)),
#  (tensor([ 33, 641,  24,   4]), tensor(1059)),
#  (tensor([ 641, 1059,    4, 1022]), tensor(24)),
#  (tensor([1059,   24, 1022,  290]), tensor(4)),
#  (tensor([ 24,   4, 290, 211]), tensor(1022)),
#  (tensor([   4, 1022,  211,   56]), tensor(290)),
#  (tensor([1022,  290,   56,    3]), tensor(211)),
#  (tensor([290, 211,   3,  31]), tensor(56)),
#  (tensor([211,  56,  31,  19]), tensor(3)),
#  (tensor([56,  3, 19,  5]), tensor(31)),
#  (tensor([ 3, 31,  5,  2]), tensor(19)),
#  (tensor([  1, 880, 215,  52]), tensor(93)),
#  (tensor([880,  93,  52, 410]), tensor(215)),
#  (tensor([  93,  215,  410, 4837]), tensor(52)),
#  (tensor([ 215,   52, 4837,    4]), tensor(410)),
#  (tensor([ 52, 410,   4, 328]), tensor(4837)),
#  (tensor([ 410, 4837,  328,    5]), tensor(4)),
#  (tensor([4837,    4,    5,    2]), tensor(328)),
#  (tensor([  1,  12,  24, 418]), tensor(2815)),
#  (tensor([  12, 2815,  418, 3247]), tensor(24)),
#  (tensor([2815,   24, 3247,    6]), tensor(418)),
#  (tensor([ 24, 418,   6, 476]), tensor(3247)),
#  (tensor([ 418, 3247,  476,   13]), tensor(6)),
#  (tensor([3247,    6,   13,    4]), tensor(476)),
#  (tensor([  6, 476,   4, 273]), tensor(13)),
#  (tensor([ 476,   13,  273, 1547]), tensor(4)),
#  (tensor([  13,    4, 1547,  679]), tensor(273)),
#  (tensor([   4,  273,  679, 3550]), tensor(1547)),
#  (tensor([ 273, 1547, 3550,    3]), tensor(679)),
#  (tensor([1547,  679,    3,   13]), tensor(3550)),
#  (tensor([ 679, 3550,   13,  433]), tensor(3)),
#  (tensor([3550,    3,  433,    3]), tensor(13)),
#  (tensor([ 3, 13,  3, 10]), tensor(433)),
#  (tensor([ 13, 433,  10,  40]), tensor(3)),
#  (tensor([ 433,    3,   40, 4616]), tensor(10)),
#  (tensor([   3,   10, 4616,  985]), tensor(40)),
#  (tensor([ 10,  40, 985,   7]), tensor(4616)),
#  (tensor([  40, 4616,    7,    4]), tensor(985)),
#  (tensor([4616,  985,    4,  245]), tensor(7)),
#  (tensor([985,   7, 245,   3]), tensor(4)),
#  (tensor([ 7,  4,  3, 14]), tensor(245)),
#  (tensor([  4, 245,  14,   4]), tensor(3)),
#  (tensor([245,   3,   4, 308]), tensor(14)),
#  (tensor([  3,  14, 308, 328]), tensor(4)),
#  (tensor([ 14,   4, 328,  16]), tensor(308)),
#  (tensor([  4, 308,  16,  41]), tensor(328)),
#  (tensor([ 308,  328,   41, 5443]), tensor(16)),
#  (tensor([ 328,   16, 5443,  975]), tensor(41)),
#  (tensor([ 16,  41, 975,   4]), tensor(5443)),
#  (tensor([  41, 5443,    4,  542]), tensor(975)),
#  (tensor([5443,  975,  542,  387]), tensor(4)),
#  (tensor([975,   4, 387, 543]), tensor(542)),
#  (tensor([  4, 542, 543,  20]), tensor(387)),
#  (tensor([ 542,  387,   20, 3862]), tensor(543)),
#  (tensor([ 387,  543, 3862,   27]), tensor(20)),
#  (tensor([543,  20,  27,  46]), tensor(3862)),
#  (tensor([  20, 3862,   46,  597]), tensor(27)),
#  (tensor([3862,   27,  597,    7]), tensor(46)),
#  (tensor([  27,   46,    7, 1238]), tensor(597)),
#  (tensor([  46,  597, 1238,  169]), tensor(7)),
#  (tensor([ 597,    7,  169, 5074]), tensor(1238)),
#  (tensor([   7, 1238, 5074,    5]), tensor(169)),
#  (tensor([1238,  169,    5,   17]), tensor(5074)),
#  (tensor([ 169, 5074,   17,    2]), tensor(5)),
#  (tensor([   1, 1084,   74,  612]), tensor(7)),
#  (tensor([1084,    7,  612,    3]), tensor(74)),
#  (tensor([ 7, 74,  3,  4]), tensor(612)),
#  (tensor([ 74, 612,   4, 651]), tensor(3)),
#  (tensor([612,   3, 651, 328]), tensor(4)),
#  (tensor([  3,   4, 328,  41]), tensor(651)),
#  (tensor([  4, 651,  41, 748]), tensor(328)),
#  (tensor([ 651,  328,  748, 2022]), tensor(41)),
#  (tensor([ 328,   41, 2022, 1274]), tensor(748)),
#  (tensor([  41,  748, 1274,   20]), tensor(2022)),
#  (tensor([ 748, 2022,   20,   46]), tensor(1274)),
#  (tensor([2022, 1274,   46,   51]), tensor(20)),
#  (tensor([1274,   20,   51,    8]), tensor(46)),
#  (tensor([ 20,  46,   8, 659]), tensor(51)),
#  (tensor([ 46,  51, 659,   5]), tensor(8)),
#  (tensor([51,  8,  5,  2]), tensor(659)),
#  (tensor([ 1, 12, 11, 28]), tensor(245)),
#  (tensor([ 12, 245,  28, 568]), tensor(11)),
#  (tensor([ 245,   11,  568, 2345]), tensor(28)),
#  (tensor([  11,   28, 2345, 4041]), tensor(568)),
#  (tensor([  28,  568, 4041,  215]), tensor(2345)),
#  (tensor([ 568, 2345,  215,  612]), tensor(4041)),
#  (tensor([2345, 4041,  612,    5]), tensor(215)),
#  (tensor([4041,  215,    5,    2]), tensor(612)),
#  (tensor([   1,   12,   33, 4117]), tensor(652)),
#  (tensor([  12,  652, 4117, 1274]), tensor(33)),
#  (tensor([ 652,   33, 1274, 4935]), tensor(4117)),
#  (tensor([  33, 4117, 4935, 4051]), tensor(1274)),
#  (tensor([4117, 1274, 4051,    3]), tensor(4935)),
#  (tensor([1274, 4935,    3,  119]), tensor(4051)),
#  (tensor([4935, 4051,  119,   29]), tensor(3)),
#  (tensor([4051,    3,   29,  135]), tensor(119)),
#  (tensor([  3, 119, 135,   3]), tensor(29)),
#  (tensor([ 119,   29,    3, 2071]), tensor(135)),
#  (tensor([  29,  135, 2071,    3]), tensor(3)),
#  (tensor([135,   3,   3, 756]), tensor(2071)),
#  (tensor([   3, 2071,  756,    9]), tensor(3)),
#  (tensor([2071,    3,    9,  807]), tensor(756)),
#  (tensor([  3, 756, 807,   9]), tensor(9)),
#  (tensor([756,   9,   9, 750]), tensor(807)),
#  (tensor([  9, 807, 750,   3]), tensor(9)),
#  (tensor([807,   9,   3,  28]), tensor(750)),
#  (tensor([  9, 750,  28, 568]), tensor(3)),
#  (tensor([750,   3, 568,  19]), tensor(28)),
#  (tensor([ 3, 28, 19,  5]), tensor(568)),
#  (tensor([ 28, 568,   5,   2]), tensor(19)),
#  (tensor([  1,  12, 652,  71]), tensor(308)),
#  (tensor([ 12, 308,  71,  41]), tensor(652)),
#  (tensor([308, 652,  41,  23]), tensor(71)),
#  (tensor([ 652,   71,   23, 1458]), tensor(41)),
#  (tensor([  71,   41, 1458,   24]), tensor(23)),
#  (tensor([41, 23, 24,  4]), tensor(1458)),
#  (tensor([  23, 1458,    4,  500]), tensor(24)),
#  (tensor([1458,   24,  500,  403]), tensor(4)),
#  (tensor([ 24,   4, 403, 455]), tensor(500)),
#  (tensor([  4, 500, 455,   7]), tensor(403)),
#  (tensor([500, 403,   7, 493]), tensor(455)),
#  (tensor([403, 455, 493, 520]), tensor(7)),
#  (tensor([455,   7, 520,   3]), tensor(493)),
#  (tensor([  7, 493,   3,  31]), tensor(520)),
#  (tensor([493, 520,  31,  19]), tensor(3)),
#  (tensor([520,   3,  19,   5]), tensor(31)),
#  (tensor([ 3, 31,  5,  2]), tensor(19)),
#  (tensor([   1, 2819,   23, 1851]), tensor(41)),
#  (tensor([2819,   41, 1851,    7]), tensor(23)),
#  (tensor([  41,   23,    7, 5036]), tensor(1851)),
#  (tensor([  23, 1851, 5036,   10]), tensor(7)),
#  (tensor([1851,    7,   10,  481]), tensor(5036)),
#  (tensor([   7, 5036,  481, 5032]), tensor(10)),
#  (tensor([5036,   10, 5032, 5391]), tensor(481)),
#  (tensor([  10,  481, 5391,    4]), tensor(5032)),
#  (tensor([ 481, 5032,    4, 2092]), tensor(5391)),
#  (tensor([5032, 5391, 2092,    6]), tensor(4)),
#  (tensor([5391,    4,    6,  500]), tensor(2092)),
#  (tensor([   4, 2092,  500,   52]), tensor(6)),
#  (tensor([2092,    6,   52, 1951]), tensor(500)),
#  (tensor([   6,  500, 1951,    7]), tensor(52)),
#  (tensor([500,  52,   7, 493]), tensor(1951)),
#  (tensor([  52, 1951,  493,  520]), tensor(7)),
#  (tensor([1951,    7,  520,   24]), tensor(493)),
#  (tensor([  7, 493,  24,  90]), tensor(520)),
#  (tensor([493, 520,  90,   5]), tensor(24)),
#  (tensor([520,  24,   5,   2]), tensor(90)),
#  (tensor([   1, 2832,    8, 1060]), tensor(29)),
#  (tensor([2832,   29, 1060,    3]), tensor(8)),
#  (tensor([29,  8,  3, 28]), tensor(1060)),
#  (tensor([   8, 1060,   28,  568]), tensor(3)),
#  (tensor([1060,    3,  568,   19]), tensor(28)),
#  (tensor([ 3, 28, 19,  3]), tensor(568)),
#  (tensor([ 28, 568,   3,   4]), tensor(19)),
#  (tensor([ 568,   19,    4, 1274]), tensor(3)),
#  (tensor([  19,    3, 1274,  455]), tensor(4)),
#  (tensor([  3,   4, 455, 175]), tensor(1274)),
#  (tensor([   4, 1274,  175,    4]), tensor(455)),
#  (tensor([1274,  455,    4,  308]), tensor(175)),
#  (tensor([455, 175, 308, 652]), tensor(4)),
#  (tensor([175,   4, 652,  16]), tensor(308)),
#  (tensor([  4, 308,  16,  33]), tensor(652)),
#  (tensor([308, 652,  33,  23]), tensor(16)),
#  (tensor([652,  16,  23,  26]), tensor(33)),
#  (tensor([  16,   33,   26, 2052]), tensor(23)),
#  (tensor([  33,   23, 2052,   29]), tensor(26)),
#  (tensor([ 23,  26,  29, 953]), tensor(2052)),
#  (tensor([  26, 2052,  953,    3]), tensor(29)),
#  (tensor([2052,   29,    3,  124]), tensor(953)),
#  (tensor([ 29, 953, 124,  75]), tensor(3)),
#  (tensor([953,   3,  75,  46]), tensor(124)),
#  (tensor([  3, 124,  46, 118]), tensor(75)),
#  (tensor([124,  75, 118,   3]), tensor(46)),
#  (tensor([75, 46,  3, 13]), tensor(118)),
#  (tensor([ 46, 118,  13, 111]), tensor(3)),
#  (tensor([118,   3, 111, 966]), tensor(13)),
#  (tensor([  3,  13, 966, 826]), tensor(111)),
#  (tensor([ 13, 111, 826,   5]), tensor(966)),
#  (tensor([111, 966,   5,  17]), tensor(826)),
#  (tensor([966, 826,  17,   2]), tensor(5)),
#  (tensor([   1,   68, 2940,    3]), tensor(705)),
#  (tensor([ 68, 705,   3,  82]), tensor(2940)),
#  (tensor([ 705, 2940,   82,    6]), tensor(3)),
#  (tensor([2940,    3,    6, 3014]), tensor(82)),
#  (tensor([   3,   82, 3014,    3]), tensor(6)),
#  (tensor([82,  6,  3,  8]), tensor(3014)),
#  (tensor([   6, 3014,    8, 1134]), tensor(3)),
#  (tensor([3014,    3, 1134, 3110]), tensor(8)),
#  (tensor([   3,    8, 3110,    3]), tensor(1134)),
#  (tensor([   8, 1134,    3, 2923]), tensor(3110)),
#  (tensor([1134, 3110, 2923,    3]), tensor(3)),
#  (tensor([3110,    3,    3,   43]), tensor(2923)),
#  (tensor([   3, 2923,   43,   14]), tensor(3)),
#  (tensor([2923,    3,   14, 4863]), tensor(43)),
#  (tensor([   3,   43, 4863,    9]), tensor(14)),
#  (tensor([  43,   14,    9, 2236]), tensor(4863)),
#  (tensor([  14, 4863, 2236,    4]), tensor(9)),
#  (tensor([4863,    9,    4, 2023]), tensor(2236)),
#  (tensor([   9, 2236, 2023, 1247]), tensor(4)),
#  (tensor([2236,    4, 1247,    3]), tensor(2023)),
#  (tensor([   4, 2023,    3,   19]), tensor(1247)),
#  (tensor([2023, 1247,   19,    4]), tensor(3)),
#  (tensor([1247,    3,    4, 1022]), tensor(19)),
#  (tensor([   3,   19, 1022,   18]), tensor(4)),
#  (tensor([  19,    4,   18, 5726]), tensor(1022)),
#  (tensor([   4, 1022, 5726,  118]), tensor(18)),
#  (tensor([1022,   18,  118, 5651]), tensor(5726)),
#  (tensor([  18, 5726, 5651,   14]), tensor(118)),
#  (tensor([5726,  118,   14,  979]), tensor(5651)),
#  (tensor([ 118, 5651,  979,  305]), tensor(14)),
#  (tensor([5651,   14,  305,  117]), tensor(979)),
#  (tensor([  14,  979,  117, 1951]), tensor(305)),
#  (tensor([ 979,  305, 1951,    7]), tensor(117)),
#  (tensor([305, 117,   7, 493]), tensor(1951)),
#  (tensor([ 117, 1951,  493,    4]), tensor(7)),
#  (tensor([1951,    7,    4,  520]), tensor(493)),
#  (tensor([  7, 493, 520,   5]), tensor(4)),
#  (tensor([493,   4,   5,   2]), tensor(520)),
#  (tensor([   1,  571,  410, 1780]), tensor(111)),
#  (tensor([ 571,  111, 1780,    4]), tensor(410)),
#  (tensor([111, 410,   4, 245]), tensor(1780)),
#  (tensor([ 410, 1780,  245,    7]), tensor(4)),
#  (tensor([1780,    4,    7, 1029]), tensor(245)),
#  (tensor([   4,  245, 1029,  500]), tensor(7)),
#  (tensor([245,   7, 500,   7]), tensor(1029)),
#  (tensor([   7, 1029,    7,  236]), tensor(500)),
#  (tensor([1029,  500,  236,   58]), tensor(7)),
#  (tensor([500,   7,  58, 643]), tensor(236)),
#  (tensor([  7, 236, 643,   9]), tensor(58)),
#  (tensor([236,  58,   9, 135]), tensor(643)),
#  (tensor([ 58, 643, 135, 974]), tensor(9)),
#  (tensor([643,   9, 974,   3]), tensor(135)),
#  (tensor([  9, 135,   3,  75]), tensor(974)),
#  (tensor([135, 974,  75,   8]), tensor(3)),
#  (tensor([974,   3,   8, 150]), tensor(75)),
#  (tensor([  3,  75, 150, 440]), tensor(8)),
#  (tensor([ 75,   8, 440,   5]), tensor(150)),
#  (tensor([  8, 150,   5,   2]), tensor(440)),
#  (tensor([  1,  68, 568,  19]), tensor(28)),
#  (tensor([68, 28, 19, 14]), tensor(568)),
#  (tensor([ 28, 568,  14, 176]), tensor(19)),
#  (tensor([568,  19, 176,   4]), tensor(14)),
#  (tensor([ 19,  14,   4, 245]), tensor(176)),
#  (tensor([  14,  176,  245, 5107]), tensor(4)),
#  (tensor([ 176,    4, 5107,   52]), tensor(245)),
#  (tensor([   4,  245,   52, 1273]), tensor(5107)),
#  (tensor([ 245, 5107, 1273,    3]), tensor(52)),
#  (tensor([5107,   52,    3,    4]), tensor(1273)),
#  (tensor([  52, 1273,    4,  387]), tensor(3)),
#  (tensor([1273,    3,  387, 5508]), tensor(4)),
#  (tensor([   3,    4, 5508,  174]), tensor(387)),
#  (tensor([  4, 387, 174,  88]), tensor(5508)),
#  (tensor([ 387, 5508,   88,    7]), tensor(174)),
#  (tensor([5508,  174,    7,  157]), tensor(88)),
#  (tensor([174,  88, 157, 118]), tensor(7)),
#  (tensor([ 88,   7, 118,   5]), tensor(157)),
#  (tensor([  7, 157,   5,   2]), tensor(118)),
#  (tensor([  1, 473, 460,   7]), tensor(52)),
#  (tensor([473,  52,   7, 596]), tensor(460)),
#  (tensor([ 52, 460, 596,   4]), tensor(7)),
#  (tensor([460,   7,   4, 455]), tensor(596)),
#  (tensor([   7,  596,  455, 1455]), tensor(4)),
#  (tensor([ 596,    4, 1455,  401]), tensor(455)),
#  (tensor([   4,  455,  401, 2368]), tensor(1455)),
#  (tensor([ 455, 1455, 2368,   58]), tensor(401)),
#  (tensor([1455,  401,   58, 5136]), tensor(2368)),
#  (tensor([ 401, 2368, 5136,   10]), tensor(58)),
#  (tensor([2368,   58,   10,  417]), tensor(5136)),
#  (tensor([  58, 5136,  417,    3]), tensor(10)),
#  (tensor([5136,   10,    3,   31]), tensor(417)),
#  (tensor([ 10, 417,  31, 373]), tensor(3)),
#  (tensor([417,   3, 373,   5]), tensor(31)),
#  (tensor([ 3, 31,  5,  2]), tensor(373)),
#  (tensor([  1,  12,  41, 502]), tensor(245)),
#  (tensor([ 12, 245, 502,  23]), tensor(41)),
#  (tensor([ 245,   41,   23, 3517]), tensor(502)),
#  (tensor([  41,  502, 3517,    7]), tensor(23)),
#  (tensor([ 502,   23,    7, 4610]), tensor(3517)),
#  (tensor([  23, 3517, 4610,   14]), tensor(7)),
#  (tensor([3517,    7,   14,  455]), tensor(4610)),
#  (tensor([   7, 4610,  455,  500]), tensor(14)),
#  (tensor([4610,   14,  500,    7]), tensor(455)),
#  (tensor([ 14, 455,   7, 493]), tensor(500)),
#  (tensor([455, 500, 493, 826]), tensor(7)),
#  (tensor([500,   7, 826,  24]), tensor(493)),
#  (tensor([  7, 493,  24,   8]), tensor(826)),
#  (tensor([493, 826,   8,  46]), tensor(24)),
#  (tensor([ 826,   24,   46, 5547]), tensor(8)),
#  (tensor([  24,    8, 5547,  920]), tensor(46)),
#  (tensor([  8,  46, 920,   3]), tensor(5547)),
#  (tensor([  46, 5547,    3,   31]), tensor(920)),
#  (tensor([5547,  920,   31,   19]), tensor(3)),
#  (tensor([920,   3,  19,   5]), tensor(31)),
#  (tensor([ 3, 31,  5,  2]), tensor(19)),
#  (tensor([  1,  12,  11, 300]), tensor(1354)),
#  (tensor([  12, 1354,  300,  791]), tensor(11)),
#  (tensor([1354,   11,  791,  170]), tensor(300)),
#  (tensor([ 11, 300, 170,   3]), tensor(791)),
#  (tensor([300, 791,   3,  45]), tensor(170)),
#  (tensor([ 791,  170,   45, 4853]), tensor(3)),
#  (tensor([ 170,    3, 4853,   25]), tensor(45)),
#  (tensor([   3,   45,   25, 1529]), tensor(4853)),
#  (tensor([  45, 4853, 1529,   98]), tensor(25)),
#  (tensor([4853,   25,   98,   13]), tensor(1529)),
#  (tensor([  25, 1529,   13, 1842]), tensor(98)),
#  (tensor([1529,   98, 1842,  752]), tensor(13)),
#  (tensor([ 98,  13, 752,   3]), tensor(1842)),
#  (tensor([  13, 1842,    3,  515]), tensor(752)),
#  (tensor([1842,  752,  515,    7]), tensor(3)),
#  (tensor([752,   3,   7, 445]), tensor(515)),
#  (tensor([  3, 515, 445,  91]), tensor(7)),
#  (tensor([515,   7,  91,  63]), tensor(445)),
#  (tensor([  7, 445,  63, 257]), tensor(91)),
#  (tensor([445,  91, 257, 446]), tensor(63)),
#  (tensor([ 91,  63, 446,   7]), tensor(257)),
#  (tensor([ 63, 257,   7,  40]), tensor(446)),
#  (tensor([ 257,  446,   40, 2396]), tensor(7)),
#  (tensor([ 446,    7, 2396,   34]), tensor(40)),
#  (tensor([   7,   40,   34, 1367]), tensor(2396)),
#  (tensor([  40, 2396, 1367,    5]), tensor(34)),
#  (tensor([2396,   34,    5,    2]), tensor(1367)),
#  (tensor([   1,   12, 1112,    9]), tensor(3356)),
#  (tensor([  12, 3356,    9, 2709]), tensor(1112)),
#  (tensor([3356, 1112, 2709, 2724]), tensor(9)),
#  (tensor([1112,    9, 2724, 3261]), tensor(2709)),
#  (tensor([   9, 2709, 3261, 2898]), tensor(2724)),
#  (tensor([2709, 2724, 2898,  867]), tensor(3261)),
#  (tensor([2724, 3261,  867,   19]), tensor(2898)),
#  (tensor([3261, 2898,   19,   27]), tensor(867)),
#  (tensor([2898,  867,   27,   33]), tensor(19)),
#  (tensor([ 867,   19,   33, 2030]), tensor(27)),
#  (tensor([  19,   27, 2030,    8]), tensor(33)),
#  (tensor([ 27,  33,   8, 115]), tensor(2030)),
#  (tensor([  33, 2030,  115,    9]), tensor(8)),
#  (tensor([2030,    8,    9,  485]), tensor(115)),
#  (tensor([  8, 115, 485, 170]), tensor(9)),
#  (tensor([115,   9, 170,  14]), tensor(485)),
#  (tensor([  9, 485,  14,  33]), tensor(170)),
#  (tensor([ 485,  170,   33, 1318]), tensor(14)),
#  (tensor([ 170,   14, 1318,   10]), tensor(33)),
#  (tensor([14, 33, 10, 16]), tensor(1318)),
#  (tensor([  33, 1318,   16, 5329]), tensor(10)),
#  (tensor([1318,   10, 5329, 1031]), tensor(16)),
#  (tensor([  10,   16, 1031,   17]), tensor(5329)),
#  (tensor([  16, 5329,   17,  114]), tensor(1031)),
#  (tensor([5329, 1031,  114,    3]), tensor(17)),
#  (tensor([1031,   17,    3,    9]), tensor(114)),
#  (tensor([ 17, 114,   9,   8]), tensor(3)),
#  (tensor([114,   3,   8, 485]), tensor(9)),
#  (tensor([  3,   9, 485, 170]), tensor(8)),
#  (tensor([  9,   8, 170,   5]), tensor(485)),
#  (tensor([  8, 485,   5,   2]), tensor(170)),
#  (tensor([  1, 681,  32, 294]), tensor(335)),
#  (tensor([681, 335, 294,   7]), tensor(32)),
#  (tensor([335,  32,   7, 921]), tensor(294)),
#  (tensor([ 32, 294, 921, 788]), tensor(7)),
#  (tensor([294,   7, 788, 729]), tensor(921)),
#  (tensor([  7, 921, 729, 700]), tensor(788)),
#  (tensor([921, 788, 700, 218]), tensor(729)),
#  (tensor([788, 729, 218,   3]), tensor(700)),
#  (tensor([729, 700,   3, 818]), tensor(218)),
#  (tensor([700, 218, 818,   7]), tensor(3)),
#  (tensor([218,   3,   7, 476]), tensor(818)),
#  (tensor([  3, 818, 476,   9]), tensor(7)),
#  (tensor([818,   7,   9, 471]), tensor(476)),
#  (tensor([  7, 476, 471, 860]), tensor(9)),
#  (tensor([476,   9, 860, 728]), tensor(471)),
#  (tensor([  9, 471, 728,   5]), tensor(860)),
#  (tensor([471, 860,   5,   2]), tensor(728)),
#  (tensor([  1, 179, 752,   7]), tensor(40)),
#  (tensor([ 179,   40,    7, 2246]), tensor(752)),
#  (tensor([  40,  752, 2246,   44]), tensor(7)),
#  (tensor([752,   7,  44,  13]), tensor(2246)),
#  (tensor([   7, 2246,   13,    4]), tensor(44)),
#  (tensor([2246,   44,    4,  446]), tensor(13)),
#  (tensor([ 44,  13, 446,   3]), tensor(4)),
#  (tensor([13,  4,  3,  8]), tensor(446)),
#  (tensor([   4,  446,    8, 1842]), tensor(3)),
#  (tensor([ 446,    3, 1842,   71]), tensor(8)),
#  (tensor([  3,   8,  71, 444]), tensor(1842)),
#  (tensor([   8, 1842,  444, 1772]), tensor(71)),
#  (tensor([1842,   71, 1772,    4]), tensor(444)),
#  (tensor([ 71, 444,   4, 447]), tensor(1772)),
#  (tensor([ 444, 1772,  447,    5]), tensor(4)),
#  (tensor([1772,    4,    5,    2]), tensor(447)),
#  (tensor([  1, 477, 386,  32]), tensor(2540)),
#  (tensor([ 477, 2540,   32,  171]), tensor(386)),
#  (tensor([2540,  386,  171,    6]), tensor(32)),
#  (tensor([386,  32,   6,   4]), tensor(171)),
#  (tensor([ 32, 171,   4, 791]), tensor(6)),
#  (tensor([171,   6, 791, 170]), tensor(4)),
#  (tensor([  6,   4, 170,   5]), tensor(791)),
#  (tensor([  4, 791,   5,   2]), tensor(170)),
#  (tensor([   1,   12,  446, 1214]), tensor(63)),
#  (tensor([  12,   63, 1214,   79]), tensor(446)),
#  (tensor([ 63, 446,  79, 171]), tensor(1214)),
#  (tensor([ 446, 1214,  171,    6]), tensor(79)),
#  (tensor([1214,   79,    6,   36]), tensor(171)),
#  (tensor([ 79, 171,  36, 225]), tensor(6)),
#  (tensor([171,   6, 225,  14]), tensor(36)),
#  (tensor([ 6, 36, 14,  4]), tensor(225)),
#  (tensor([ 36, 225,   4, 791]), tensor(14)),
#  (tensor([225,  14, 791, 170]), tensor(4)),
#  (tensor([ 14,   4, 170,   3]), tensor(791)),
#  (tensor([  4, 791,   3, 175]), tensor(170)),
#  (tensor([791, 170, 175, 640]), tensor(3)),
#  (tensor([170,   3, 640,   7]), tensor(175)),
#  (tensor([   3,  175,    7, 5113]), tensor(640)),
#  (tensor([ 175,  640, 5113,   40]), tensor(7)),
#  (tensor([ 640,    7,   40, 2285]), tensor(5113)),
#  (tensor([   7, 5113, 2285, 1368]), tensor(40)),
#  (tensor([5113,   40, 1368,  652]), tensor(2285)),
#  (tensor([  40, 2285,  652,    9]), tensor(1368)),
#  (tensor([2285, 1368,    9,    7]), tensor(652)),
#  (tensor([1368,  652,    7, 1023]), tensor(9)),
#  (tensor([ 652,    9, 1023,   46]), tensor(7)),
#  (tensor([  9,   7,  46, 257]), tensor(1023)),
#  (tensor([   7, 1023,  257,  446]), tensor(46)),
#  (tensor([1023,   46,  446,    3]), tensor(257)),
#  (tensor([ 46, 257,   3, 804]), tensor(446)),
#  (tensor([257, 446, 804,  30]), tensor(3)),
#  (tensor([446,   3,  30,   4]), tensor(804)),
#  (tensor([  3, 804,   4, 245]), tensor(30)),
#  (tensor([804,  30, 245,  10]), tensor(4)),
#  (tensor([ 30,   4,  10, 861]), tensor(245)),
#  (tensor([  4, 245, 861,   5]), tensor(10)),
#  (tensor([245,  10,   5,   2]), tensor(861)),
#  (tensor([   1,   12,   16, 2256]), tensor(63)),
#  (tensor([  12,   63, 2256, 1831]), tensor(16)),
#  (tensor([  63,   16, 1831,   17]), tensor(2256)),
#  (tensor([  16, 2256,   17,  170]), tensor(1831)),
#  (tensor([2256, 1831,  170,   33]), tensor(17)),
#  (tensor([1831,   17,   33, 5288]), tensor(170)),
#  (tensor([  17,  170, 5288,   94]), tensor(33)),
#  (tensor([170,  33,  94,   6]), tensor(5288)),
#  (tensor([  33, 5288,    6,  114]), tensor(94)),
#  (tensor([5288,   94,  114, 2057]), tensor(6)),
#  (tensor([  94,    6, 2057,    7]), tensor(114)),
#  (tensor([  6, 114,   7, 578]), tensor(2057)),
#  (tensor([ 114, 2057,  578, 2685]), tensor(7)),
#  (tensor([2057,    7, 2685,    3]), tensor(578)),
#  (tensor([  7, 578,   3, 787]), tensor(2685)),
#  (tensor([ 578, 2685,  787,  450]), tensor(3)),
#  (tensor([2685,    3,  450,    9]), tensor(787)),
#  (tensor([  3, 787,   9,  10]), tensor(450)),
#  (tensor([787, 450,  10,  74]), tensor(9)),
#  (tensor([ 450,    9,   74, 1821]), tensor(10)),
#  (tensor([   9,   10, 1821,    3]), tensor(74)),
#  (tensor([  10,   74,    3, 1667]), tensor(1821)),
#  (tensor([  74, 1821, 1667, 3016]), tensor(3)),
#  (tensor([1821,    3, 3016,    5]), tensor(1667)),
#  (tensor([   3, 1667,    5,    2]), tensor(3016)),
#  (tensor([   1, 2697,   33,   23]), tensor(4174)),
#  (tensor([2697, 4174,   23,  769]), tensor(33)),
#  (tensor([4174,   33,  769,   10]), tensor(23)),
#  (tensor([ 33,  23,  10, 114]), tensor(769)),
#  (tensor([ 23, 769, 114,  30]), tensor(10)),
#  (tensor([769,  10,  30,  16]), tensor(114)),
#  (tensor([  10,  114,   16, 1042]), tensor(30)),
#  (tensor([ 114,   30, 1042,   17]), tensor(16)),
#  (tensor([ 30,  16,  17, 169]), tensor(1042)),
#  (tensor([  16, 1042,  169, 5403]), tensor(17)),
#  (tensor([1042,   17, 5403,   21]), tensor(169)),
#  (tensor([ 17, 169,  21, 664]), tensor(5403)),
#  (tensor([ 169, 5403,  664, 2069]), tensor(21)),
#  (tensor([5403,   21, 2069,    3]), tensor(664)),
#  (tensor([  21,  664,    3, 3497]), tensor(2069)),
#  (tensor([ 664, 2069, 3497, 3647]), tensor(3)),
#  (tensor([2069,    3, 3647,   48]), tensor(3497)),
#  (tensor([   3, 3497,   48, 2315]), tensor(3647)),
#  (tensor([3497, 3647, 2315,    5]), tensor(48)),
#  (tensor([3647,   48,    5,    2]), tensor(2315)),
#  (tensor([   1, 3312,    6,    4]), tensor(4894)),
#  (tensor([3312, 4894,    4,  170]), tensor(6)),
#  (tensor([4894,    6,  170,   33]), tensor(4)),
#  (tensor([ 6,  4, 33, 23]), tensor(170)),
#  (tensor([   4,  170,   23, 4537]), tensor(33)),
#  (tensor([ 170,   33, 4537,   10]), tensor(23)),
#  (tensor([  33,   23,   10, 1046]), tensor(4537)),
#  (tensor([  23, 4537, 1046,    3]), tensor(10)),
#  (tensor([4537,   10,    3,   30]), tensor(1046)),
#  (tensor([  10, 1046,   30,    4]), tensor(3)),
#  (tensor([1046,    3,    4,  808]), tensor(30)),
#  (tensor([  3,  30, 808, 297]), tensor(4)),
#  (tensor([ 30,   4, 297,  80]), tensor(808)),
#  (tensor([  4, 808,  80, 145]), tensor(297)),
#  (tensor([808, 297, 145,  48]), tensor(80)),
#  (tensor([297,  80,  48, 526]), tensor(145)),
#  (tensor([ 80, 145, 526, 769]), tensor(48)),
#  (tensor([145,  48, 769,   5]), tensor(526)),
#  (tensor([ 48, 526,   5,   2]), tensor(769)),
#  (tensor([  1,  12, 170,  33]), tensor(485)),
#  (tensor([  12,  485,   33, 1318]), tensor(170)),
#  (tensor([ 485,  170, 1318,   10]), tensor(33)),
#  (tensor([ 170,   33,   10, 4405]), tensor(1318)),
#  (tensor([  33, 1318, 4405,   48]), tensor(10)),
#  (tensor([1318,   10,   48, 4698]), tensor(4405)),
#  (tensor([  10, 4405, 4698,  145]), tensor(48)),
#  (tensor([4405,   48,  145,    3]), tensor(4698)),
#  (tensor([  48, 4698,    3,  304]), tensor(145)),
#  (tensor([4698,  145,  304,   48]), tensor(3)),
#  (tensor([ 145,    3,   48, 1783]), tensor(304)),
#  (tensor([   3,  304, 1783,   94]), tensor(48)),
#  (tensor([304,  48,  94,   3]), tensor(1783)),
#  (tensor([  48, 1783,    3,  299]), tensor(94)),
#  (tensor([1783,   94,  299,   29]), tensor(3)),
#  (tensor([ 94,   3,  29, 130]), tensor(299)),
#  (tensor([  3, 299, 130,  29]), tensor(29)),
#  (tensor([299,  29,  29, 270]), tensor(130)),
#  (tensor([ 29, 130, 270,  15]), tensor(29)),
#  (tensor([130,  29,  15,  10]), tensor(270)),
#  (tensor([  29,  270,   10, 1277]), tensor(15)),
#  (tensor([ 270,   15, 1277,   94]), tensor(10)),
#  (tensor([15, 10, 94,  5]), tensor(1277)),
#  (tensor([  10, 1277,    5,    2]), tensor(94)),
#  (tensor([  1,  12,  71, 158]), tensor(170)),
#  (tensor([ 12, 170, 158, 284]), tensor(71)),
#  (tensor([170,  71, 284,   9]), tensor(158)),
#  (tensor([ 71, 158,   9, 310]), tensor(284)),
#  (tensor([ 158,  284,  310, 4312]), tensor(9)),
#  (tensor([ 284,    9, 4312,    9]), tensor(310)),
#  (tensor([  9, 310,   9, 446]), tensor(4312)),
#  (tensor([ 310, 4312,  446, 1239]), tensor(9)),
#  (tensor([4312,    9, 1239,    3]), tensor(446)),
#  (tensor([  9, 446,   3, 818]), tensor(1239)),
#  (tensor([ 446, 1239,  818,    7]), tensor(3)),
#  (tensor([1239,    3,    7,  728]), tensor(818)),
#  (tensor([  3, 818, 728,  20]), tensor(7)),
#  ...]

# %%
EMDEDDING_DIM = 100

class CBOW(torch.nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(CBOW, self).__init__()
        
        #out: 1 x emdedding_dim
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear1 = nn.Linear(embedding_dim, 128)
        self.activation_function1 = nn.ReLU()       
        #out: 1 x vocab_size
        self.linear2 = nn.Linear(128, vocab_size)
        self.activation_function2 = nn.LogSoftmax(dim = -1)
        
    def forward(self, inputs):
        embeds = sum(self.embeddings(inputs)).view(1,-1)
        out = self.linear1(embeds)
        out = self.activation_function1(out)
        out = self.linear2(out)
        out = self.activation_function2(out)
        return out

model = CBOW(V, EMDEDDING_DIM)

loss_function = nn.NLLLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# %%
cbow_data = []
for ex in train_iter:
#    print(ex.pos)
    words = ex.word
    _, lengths = ex.pos
    
    for b in range(ex.word.shape[1]):
        for i in range(2, lengths[b]-2):
            context = torch.stack((ex.word[i-2, b], ex.word[i-1, b], ex.word[i+1, b], ex.word[i+2, b]))
            target = ex.word[i, b].unsqueeze(0)
            cbow_data.append((context, target))
cbow_data

for epoch in range(1):
    total_loss = 0

    for context, target in cbow_data:

        log_probs = model(context)
        total_loss += loss_function(log_probs, target)

    #optimize at the end of each epoch
    optimizer.zero_grad()
    total_loss.backward()
    optimizer.step()

# %%
model.embeddings.weight
# Out:
# Parameter containing:
# tensor([[ 0.1102,  0.2621, -0.5563,  ...,  1.4778, -2.8874, -1.8069],
#         [-0.7891, -0.0880, -0.7665,  ..., -1.0141,  0.9049,  0.6267],
#         [ 0.3524, -1.6108,  1.3594,  ..., -1.5768,  2.4414, -1.1162],
#         ...,
#         [-0.0577, -1.3942,  1.9094,  ..., -0.3939,  1.0865, -0.6199],
#         [ 0.7432,  2.3903,  0.6530,  ..., -1.2121, -0.4424,  1.1086],
#         [-0.2241,  0.8927,  1.8569,  ...,  0.4546, -2.5282, -2.5326]],
#        requires_grad=True)

# %%
cbow_data[1]
# Out:
# (tensor([  70,   36,  411, 1406]), tensor(572))

# %%
a=model(cbow_data[19][0])

# %%
WORD.vocab.itos[torch.argmax(a[0]).item()]
# Out:
# ','

# %%
print(' '.join([WORD.vocab.itos[i] for i in cbow_data[1][0]]))
print([WORD.vocab.itos[cbow_data[1][1]]] )
# Out:
# In an 19 review
# ['Oct.']

# %%
# counts for mle's 
tags = [] # prior
bigrams = [] # transition
word_tag_counts = [] # emission
for ex in train_iter:
#    print(ex.pos)
    words = ex.word
    label, lengths = ex.pos
    for batch in range(label.shape[1]):
    #    print(' '.join([WORD.vocab.itos[i] for i in words[:lengths[batch], batch]]))        
        tags.append(label[:lengths[batch], batch])
        bigrams.append(label[:lengths[batch], batch].unfold(0, 2, 1)) #dimension, size, step      
        for i, t in enumerate(label[:lengths[batch], batch]):
            word_tag_counts.append(torch.tensor((t.item(), words[i, batch].item())))
tags = torch.cat(tags, 0)
bigrams = torch.cat(bigrams, 0)
word_tag_counts = torch.stack(word_tag_counts)

# %%
# prior
init = torch.ones(C).long() # add-1 smoothing
init.index_put_((tags,), torch.tensor(1), accumulate=True)
assert init[POS.vocab.stoi['<eos>']] == len(train)+1
init = init.float() / init.sum()
assert torch.isclose(init.sum(), torch.tensor(1.))# \sum_C p_c = 1
init = init.log()

# %%
init.type()

# %%
# transition
transition = torch.ones((C, C)).long() # p(. | eos) = 1/C
transition.index_put_((bigrams[:, 0], bigrams[:, 1]), torch.tensor(1), accumulate=True)
transition = (transition.float() / transition.sum(-1, keepdim=True)).transpose(0, 1) 
assert torch.isclose(transition.sum(0, keepdim=True).sum(), \
        torch.tensor(C, dtype=torch.float)) # should be for x in C-{eos}, sum_C  p(c, x) = 1?
transition = transition.log()

# %%
# emission 
emission = torch.ones((C, V)).long()
emission.index_put_((word_tag_counts[:, 0], word_tag_counts[:, 1]), torch.tensor(1), accumulate=True)
emission = (emission.float() / emission.sum(-1, keepdim=True)).transpose(0, 1)
assert torch.isclose(emission.sum(0, keepdim=True).sum(), \
        torch.tensor(C, dtype=torch.float)) # sum_V p(v | c) = 1
emission = emission.log()

# %%
transition.shape

# %%
emission.shape

# %%
init.shape

# %%
observations = torch.LongTensor(next(iter(test_iter)).word).transpose(0, 1).contiguous()    
observations.shape

# %%
scores = torch.zeros(20, 43, C, C).type_as(emission)
scores

# %%
scores += transition.view(1, 1, C, C)
scores.shape

# %%
obs = emission[observations.view(20*44), : ]
obs.shape

# %%
obs.view(20, 44, C, 1)[:, 1:].shape

# %%
obs

# %%
obs.view(20, 44, 1, C)[:, 0].shape

# %%
torch.tensor(3)

# %%
def show_chain(chain):
    plt.imshow(chain.detach().sum(-1).transpose(0, 1))

# print('t1', time.time() - start_time)

# %%
def test(iters):
    losses = []
    total = 0
    incorrect_edges = 0 
    #model.eval()
    for i, ex in enumerate(iters):      
        observations = torch.LongTensor(ex.word).transpose(0, 1).contiguous()            
        label, lengths = ex.pos
        
#         print(transition)
        dist = HMM(transition, emission, init, observations, lengths=lengths) 
        labels = LinearChainCRF.struct.to_parts(label.transpose(0, 1) \
                .type(torch.LongTensor), C, lengths=lengths).type(torch.FloatTensor)    
        # print(HMM.struct.from_parts(dist.argmax)[0][0])
        # print('label', labels.shape)  
        # print(dist.argmax.shape)
        # show_chain(dist.argmax[0])  
        # plt.show()

        loglik = dist.log_prob(labels).sum()
        # print(loglik, label.shape[1])
        losses.append(loglik.detach()/label.shape[1])

        incorrect_edges += (dist.argmax.sum(-1) - labels.sum(-1)).abs().sum() / 2.0
        total += dist.argmax.sum()         

    print(total, incorrect_edges)
    print('inaccurate', incorrect_edges / total) 
    return torch.tensor(losses).mean()

# print('train-log-lik', test(train_iter))
print('test-log-lik', test(test_iter))

# print("--- %s seconds ---" % (time.time() - start_time))

print(transition,"\n", emission,"\n", init )

# %%
m = torch.tensor([[1, 2], [3, 4]])
m

# %%
m.shape

# %%
torch.tensor(((1, 2), (3, 4))).unsqueeze(-1)

# %%
r = torch.randint(0, 9, (2, 3, 4, 4))
r

# %%
r[:, 1:, :, :]
